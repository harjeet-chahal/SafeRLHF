# %% [markdown]
# # Evaluation
#
# This notebook covers evaluation of trained models:
# - Loading trained policy and reward models
# - Generating responses on test set
# - Computing safety metrics
# - Visualizing results
# - Running safety probes

# %%
# TODO: Implement evaluation
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load models
# Generate responses
# Compute metrics
# Visualize results
