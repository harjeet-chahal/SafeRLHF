# %% [markdown]
# # Data Generation
#
# This notebook handles the generation of training data for SafeRLHF:
# - Loading and preprocessing prompts
# - Generating responses using base policy model
# - Creating safety labels for responses
# - Preparing datasets for reward model training

# %%
# TODO: Implement data generation
import pandas as pd
import json

# Load prompts
# Generate responses
# Create safety labels
# Save datasets
